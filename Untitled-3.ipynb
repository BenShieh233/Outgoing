# %%
from main import read_excel_files, data_preprocessing, get_tables, cal_PN,cal_qty,merge_tables
import pandas as pd
import numpy as np
import os

# %%
files = read_excel_files()
file = files[0]
# Out:
# 已获取当前路径下的月度表格：['c:\\Users\\cs\\OneDrive\\Desktop\\carro\\Outgoing\\July_15 CARRO USA OUTGOING.xlsx', 'c:\\Users\\cs\\OneDrive\\Desktop\\carro\\Outgoing\\July_24 CARRO USA OUTGOING.xlsx']

# %%
df = data_preprocessing(file)
# Out:
# 已读取所有表格
# 已筛选所有符合格式的字符串
# 已转换字符串格式并去除空格
# c:\Users\cs\OneDrive\Desktop\carro\Outgoing\main.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([pd.read_excel(file_path, sheet_name=sheet_name) for sheet_name in sheet_names[2:]], axis=0)

# %%
df_qty, df_pn = get_tables(df)[0], get_tables(df)[1]

# %%
df_qty
# Out:
#                                         SKU  \
# 0   S525B-L22-W1-1 (FAN BLADE BRACKET ONLY)
# 1                                REMOTE-204
# 2                            PN-04F01A-WH01
# 3                                PCB-443N2L
# 4                                REMOTE-201
# ..                                      ...
# 9            C523P-N10-W1-1-FM (MOTOR ONLY)
# 10           C523P-N10-W1-1-FM (MOTOR ONLY)
# 11                                PCB-523PL
# 12                               REMOTE-201
# 13                            ADAPTER-24V2A
#
#                                 Wayfair SKU Qty
# 0   S525B-L22-W1-1 (FAN BLADE BRACKET ONLY)   1
# 1                                REMOTE-204   1
# 2                            PN-04F01A-WH01   1
# 3                                PCB-443N2L   1
# 4                                REMOTE-201   1
# ..                                      ...  ..
# 9            C523P-N10-W1-1-FM (MOTOR ONLY)   1
# ...

# %%
df_pn
# Out:
#                                         SKU  \
# 0   S525B-L22-W1-1 (FAN BLADE BRACKET ONLY)
# 1                                REMOTE-204
# 2                            PN-04F01A-WH01
# 3                                PCB-443N2L
# 4                                REMOTE-201
# ..                                      ...
# 9            C523P-N10-W1-1-FM (MOTOR ONLY)
# 10           C523P-N10-W1-1-FM (MOTOR ONLY)
# 11                                PCB-523PL
# 12                               REMOTE-201
# 13                            ADAPTER-24V2A
#
#                                 Wayfair SKU Qty Problem Number
# 0   S525B-L22-W1-1 (FAN BLADE BRACKET ONLY)   1             10
# 1                                REMOTE-204   1             10
# 2                            PN-04F01A-WH01   1              8
# 3                                PCB-443N2L   1              1
# 4                                REMOTE-201   1             14
# ...

# %%
summary = merge_tables(df_qty, df_pn)
# Out:
# 已分隔多种Problem Number至不同列
# 已合并Qty与Problem Number表格
# c:\Users\cs\OneDrive\Desktop\carro\Outgoing\main.py:102: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   pivot_table = grouped.pivot_table(index=['SKU', 'Wayfair SKU'], columns='Problem_Number', values='total_qty', fill_value=0).reset_index()

# %%
summary.to_excel(f"Summary_{os.path.basename(file)}")

# %%
cal_qty(df_qty)
# Out:
#                                               SKU  \
# 0                                   ADAPTER-24V2A
# 1                                   ADAPTER-24V3A
# 2                                    ADC-REMOTE 1
# 3                                ADC-REMOTE GEN 1
# 4                                    ADPTER-24V3A
# ..                                            ...
# 600              YDC605J-L11-BG-1-FM (MOTOR ONLY)
# 601            YDC605J-L11-BO-1 (FAN BLADES ONLY)
# 602  YDC605J-L11-W1-1G (LED BOARD & MAGNETS ONLY)
# 603                 YDC605J-L12-B2-1 (MOTOR ONLY)
# 604             YDC605J-L12-B2-1G-FM (MOTOR ONLY)
#
#                                       Wayfair SKU total_qty
# 0                                   ADAPTER-24V2A       186
# 1                                   ADAPTER-24V3A        42
# 2                                    ADC-REMOTE 1         1
# 3                                ADC-REMOTE GEN 1         7
# ...

# %%
df_pn = df_pn.assign(Problem_Number=df_pn['Problem Number'].str.split('-')).explode('Problem_Number')

# %%
df_pn
# Out:
#                                            SKU  \
# 1           S525B-L22-W1-1-FM (LAMPSHADE ONLY)
# 2     S525E-L12-BO-1(LED BOARD & MAGNETS ONLY)
# 3                                   PCB-485Q5L
# 4                                ADAPTER-24V2A
# 5              S525J-L12-B5-1 (LED BOARD ONLY)
# ...                                        ...
# 1786                             ADAPTER-24V2A
# 1787          S525J1-L11-B2-1G-FM (MOTOR ONLY)
# 1788                                 PCB-525EL
# 1789                                REMOTE-201
# 1790                             ADAPTER-24V2A
#
#                                    Wayfair SKU Qty Problem Number  \
# 1           S525B-L22-W1-1-FM (LAMPSHADE ONLY)   1              8
# 2     S525E-L12-BO-1(LED BOARD & MAGNETS ONLY)   1              8
# 3                                   PCB-485Q5L   1              1
# 4                                ADAPTER-24V2A   1              1
# ...

# %%
df_pn['Problem Number'].unique()
# Out:
# array(['8', '1', '1-2', '11', '6', '3', '14', '9', '3-14', '4-5', '10',
#        '17', '7', '5', '6-12-13', '3-15', '3-8-17', '4', '16', '2', '15',
#        '5-6', '2-3', '1-6', '1-3'], dtype=object)

# %%
df_pn['Problem_Number'].unique()
# Out:
# array(['8', '1', '2', '11', '6', '3', '14', '9', '4', '5', '10', '17',
#        '7', '12', '13', '15', '16'], dtype=object)

# %%
df['PROBLEM NUMBER'].unique()
# Out:
# array([nan, 8, 1, '1-2', 11, 6, 3, 14, 9, "3'-14", "4'-5", 10, '4-5',
#        "4-5'", 'Warranty processed by China Team', 17, 7, 5, "1-2'",
#        '6, 12, 13', '3, 15', '3, 8, 17', 4, 16, 2, 15, "5-6'", '2-3',
#        '1-6', '1,2', '14 (REMOTE SHORT CIRCUIT)', '1-3'], dtype=object)

# %%
df_pn = df_pn[['SKU', 'Wayfair SKU', 'Qty', 'Problem_Number']]

# %%
grouped = df_pn.groupby(['SKU', 'Wayfair SKU', 'Problem_Number']).agg(total_qty=('Qty', 'sum')).reset_index()
grouped
# Out:
#                                               SKU  \
# 0                                   ADAPTER-24V2A
# 1                                   ADAPTER-24V2A
# 2                                   ADAPTER-24V2A
# 3                                   ADAPTER-24V2A
# 4                                   ADAPTER-24V2A
# ..                                            ...
# 823              YDC605J-L11-BG-1-FM (MOTOR ONLY)
# 824            YDC605J-L11-BO-1 (FAN BLADES ONLY)
# 825  YDC605J-L11-W1-1G (LED BOARD & MAGNETS ONLY)
# 826                 YDC605J-L12-B2-1 (MOTOR ONLY)
# 827             YDC605J-L12-B2-1G-FM (MOTOR ONLY)
#
#                                       Wayfair SKU Problem_Number total_qty
# 0                                   ADAPTER-24V2A              1         6
# 1                                   ADAPTER-24V2A             14         7
# 2                                   ADAPTER-24V2A              2         1
# ...

# %%
pivot_table = grouped.pivot_table(index=['SKU', 'Wayfair SKU'], columns='Problem_Number', values='total_qty', fill_value=0).reset_index()
pivot_table
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\cs\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\cs\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\cs\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...

# %%
grouped.to_csv("grouped.csv")
